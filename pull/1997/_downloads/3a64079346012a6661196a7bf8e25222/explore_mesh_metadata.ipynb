# %% [markdown]
# # Explore a mesh metadata {#ref_tutorials_explore_mesh_metadata}
#
# `LSDYNA`{.interpreted-text role="bdg-lsdyna"} `Fluent`{.interpreted-text
# role="bdg-fluent"} `CFX`{.interpreted-text role="bdg-cfx"}
#
# :::: note
# ::: title
# Note
# :::
#
# This tutorial requires DPF 9.1 or above (2025 R1).
# ::::
#
# This tutorial explains how to read mesh metadata (data about the
# elements, nodes, faces, regions, zones, \...) before extracting the mesh
# from a result file.
#
# The mesh metadata information is stored in a
# `PropertyField<ansys.dpf.core.property_field.PropertyField>`{.interpreted-text
# role="class"} or in a
# `StringField<ansys.dpf.core.string_field.StringField>`{.interpreted-text
# role="class"}. It describes the mesh composition and is mapped to the
# entity it is defined at. Available metadata includes:
#
# - Properties, parts, faces, bodies, zones
# - Number of nodes and elements
# - Element types

# %% [markdown]
# # Import the necessary modules

# %%
from ansys.dpf import core as dpf
from ansys.dpf.core import examples

# %% [markdown]
# # LS-DYNA --- explore mesh metadata
#
# Import the result file and create the
# `Model<ansys.dpf.core.model.Model>`{.interpreted-text role="class"}.

# %%
result_file_path_2 = examples.download_d3plot_beam()
ds_2 = dpf.DataSources()
ds_2.set_result_file_path(filepath=result_file_path_2[0], key="d3plot")
ds_2.add_file_path(filepath=result_file_path_2[3], key="actunits")
model_2 = dpf.Model(data_sources=ds_2)

# %% [markdown]
# Access the
# `MeshInfo<ansys.dpf.core.mesh_info.MeshInfo>`{.interpreted-text
# role="class"} object to explore available metadata before extracting the
# mesh.

# %%
mesh_info_2 = model_2.metadata.mesh_info
print(mesh_info_2)

# %% [markdown]
# Extract specific metadata --- here the part names.

# %%
cell_zones_2 = mesh_info_2.get_property("part_names")
print(cell_zones_2)

# %% [markdown]
# # Fluent --- explore mesh metadata

# %%
result_file_path_3 = examples.download_fluent_axial_comp()["flprj"]
model_3 = dpf.Model(data_sources=result_file_path_3)

mesh_info_3 = model_3.metadata.mesh_info
print(mesh_info_3)

# %% [markdown]
# Extract the cell zone names.

# %%
cell_zones_3 = mesh_info_3.get_property("cell_zone_names")
print(cell_zones_3)

# %% [markdown]
# # CFX --- explore mesh metadata

# %%
result_file_path_4 = examples.download_cfx_mixing_elbow()
model_4 = dpf.Model(data_sources=result_file_path_4)

mesh_info_4 = model_4.metadata.mesh_info
print(mesh_info_4)

# %% [markdown]
# Extract the cell zone names.

# %%
cell_zones_4 = mesh_info_4.get_property("cell_zone_names")
print(cell_zones_4)
